# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
import numpy as np
import pandas as pd

x=np.array([1.3, 1.5, 1.7, 2.5, 2.7, 2.5, 3.2, 3.0, 3.5, 4.2, 2.5])

y=np.array([49000, 56000, 37700, np.nan, 49800,
            56000, 60100, 55400, 57100, 65200,57600])

df=pd.DataFrame({
    "Experience":x,
    "Salary":y
})

print(df)
# Out:
#     Experience   Salary
# 0          1.3  49000.0
# 1          1.5  56000.0
# 2          1.7  37700.0
# 3          2.5      NaN
# 4          2.7  49800.0
# 5          2.5  56000.0
# 6          3.2  60100.0
# 7          3.0  55400.0
# 8          3.5  57100.0
# 9          4.2  65200.0
# 10         2.5  57600.0

# %%
plt.plot(x,y,marker="D")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Original Data-Experience vs Salary")
plt.grid()
plt.show()

# %%
df.isnull()
# Out:
#     Experience  Salary
# 0        False   False
# 1        False   False
# 2        False   False
# 3        False    True
# 4        False   False
# 5        False   False
# 6        False   False
# 7        False   False
# 8        False   False
# 9        False   False
# 10       False   False

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# dtype: bool

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Experience    0
# Salary        1
# dtype: int64

# %%
print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# Duplicate Rows:
# 0

# %%
df["Salary"]= df["Salary"].fillna(df["Salary"].mean())
df
# Out:
#     Experience   Salary
# 0          1.3  49000.0
# 1          1.5  56000.0
# 2          1.7  37700.0
# 3          2.5  54390.0
# 4          2.7  49800.0
# 5          2.5  56000.0
# 6          3.2  60100.0
# 7          3.0  55400.0
# 8          3.5  57100.0
# 9          4.2  65200.0
# 10         2.5  57600.0

# %%
df=df.drop_duplicates()
df
# Out:
#     Experience   Salary
# 0          1.3  49000.0
# 1          1.5  56000.0
# 2          1.7  37700.0
# 3          2.5  54390.0
# 4          2.7  49800.0
# 5          2.5  56000.0
# 6          3.2  60100.0
# 7          3.0  55400.0
# 8          3.5  57100.0
# 9          4.2  65200.0
# 10         2.5  57600.0

# %%
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# Experience    0
# Salary        0
# dtype: int64
# 0

# %%
plt.plot(x,y,marker="D")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Original Data-Experience vs Salary")
plt.grid()
plt.show()

# %%
x=df[["Experience"]]
y=df["Salary"]

x_train, x_test, y_train, y_test=train_test_split(
    x, y, test_size=0.2, random_state=1
)

# %%
x_test.shape
# Out:
# (3, 1)

# %%
y_train.shape
# Out:
# (8,)

# %%
y_test.shape
# Out:
# (3,)

# %%
x_train.shape
# Out:
# (8, 1)

# %%
model=LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred= model.predict(x_test)
print("Prediction value", y_pred)
# Out:
# Prediction value [53137.3392957  56228.82429663 57001.69554686]

# %%
r2=r2_score(y_test, y_pred)

print("R2 Score:", r2)
# Out:
# R2 Score: -0.9744481795833673

# %%
experience= np.array([[5]])

salary= model.predict(experience)

print("Predicted Salary for 5 Years Experience:",
      salary[0])
# Out:
# Predicted Salary for 5 Years Experience: 65889.71492453884
# /usr/local/lib/python3.13/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.plot(x,y, label="Actual Salary")
plt.plot(x, model.predict(x), label="Regression Line")

plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Linear Regression-Experience vs Salary")

plt.legend()
plt.grid()
plt.show()

# %%
df.mean()
# Out:
# Experience        2.6
# Salary        54390.0
# dtype: float64

# %%
df.std()
# Out:
# Experience       0.874071
# Salary        7085.118206
# dtype: float64

# %%
df.median()
# Out:
# Experience        2.5
# Salary        56000.0
# dtype: float64

# %%
df.corr()
# Out:
#             Experience    Salary
# Experience    1.000000  0.692422
# Salary        0.692422  1.000000

# %%
df.describe()
# Out:
#        Experience        Salary
# count   11.000000     11.000000
# mean     2.600000  54390.000000
# std      0.874071   7085.118206
# min      1.300000  37700.000000
# 25%      2.100000  52095.000000
# 50%      2.500000  56000.000000
# 75%      3.100000  57350.000000
# max      4.200000  65200.000000
